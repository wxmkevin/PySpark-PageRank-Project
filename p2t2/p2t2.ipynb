# %%
import sys

from pyspark import SparkContext
from pyspark.streaming import StreamingContext

# %%
sc = SparkContext(appName="PythonStreamingNetworkWordCount")
ssc = StreamingContext(sc, 1)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/04/27 02:41:56 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 22/04/27 02:41:56 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 22/04/27 02:41:56 INFO org.apache.spark.SparkEnv: Registering BlockManagerMasterHeartbeat
# 22/04/27 02:41:56 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator

# %%
lines = ssc.textFileStream("hdfs:///")
# counts = lines.flatMap(lambda line: line.split(" "))\
#               .map(lambda word: (word, 1))\
#               .reduceByKey(lambda a, b: a+b)
lines.pprint()

ssc.start()
ssc.awaitTermination()
# Out:
# 22/04/27 02:42:53 WARN org.apache.spark.streaming.StreamingContext: Dynamic Allocation is enabled for this application. Enabling Dynamic allocation for Spark Streaming applications can cause data loss if Write Ahead Log is not enabled for non-replayable sources. See the programming guide for details on how to enable the Write Ahead Log.
# -------------------------------------------
# Time: 2022-04-27 02:42:54
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:42:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:42:56
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:42:57
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:42:58
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:42:59
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:01
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:02
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:03
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:04
# -------------------------------------------
# -------------------------------------------
# Time: 2022-04-27 02:43:05
# -------------------------------------------
# gdaeicjdcg,194,155,98,107
# jhbcfbdigg,73,20,122,172
# ahdjfgccgd,28,47,40,178
# afeidjjcef,105,164,37,53
# afeiccfdeg,29,197,128,85
# aegddbbcii,58,126,89,28
# fjfdbfaeid,80,89,180,82
#
# -------------------------------------------
# Time: 2022-04-27 02:43:06
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:07
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:08
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:09
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:11
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:12
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:13
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:14
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:16
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:17
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:18
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:19
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:21
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:22
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:23
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-04-27 02:43:24
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 8>()
#       5 lines.pprint()
#       7 ssc.start()
# ----> 8 ssc.awaitTermination()
#
# File /usr/lib/spark/python/pyspark/streaming/context.py:199, in StreamingContext.awaitTermination(self, timeout)
#     190 """
#     191 Wait for the execution to stop.
#     192
#    (...)
#     196     time to wait in seconds
#     197 """
#     198 if timeout is None:
# --> 199     self._jssc.awaitTermination()
#     200 else:
#     201     self._jssc.awaitTerminationOrTimeout(int(timeout * 1000))
#
# File /opt/conda/miniconda3/lib/python3.8/site-packages/py4j/java_gateway.py:1303, in JavaMember.__call__(self, *args)
#    1296 args_command, temp_args = self._build_args(*args)
#    1298 command = proto.CALL_COMMAND_NAME +\
#    1299     self.command_header +\
#    1300     args_command +\
#    1301     proto.END_COMMAND_PART
# -> 1303 answer = self.gateway_client.send_command(command)
#    1304 return_value = get_return_value(
#    1305     answer, self.gateway_client, self.target_id, self.name)
#    1307 for temp_arg in temp_args:
#
# File /opt/conda/miniconda3/lib/python3.8/site-packages/py4j/java_gateway.py:1033, in GatewayClient.send_command(self, command, retry, binary)
#    1031 connection = self._get_connection()
#    1032 try:
# -> 1033     response = connection.send_command(command)
#    1034     if binary:
#    1035         return response, self._create_connection_guard(connection)
#
# File /opt/conda/miniconda3/lib/python3.8/site-packages/py4j/java_gateway.py:1200, in GatewayConnection.send_command(self, command)
#    1196     raise Py4JNetworkError(
#    1197         "Error while sending", e, proto.ERROR_ON_SEND)
#    1199 try:
# -> 1200     answer = smart_decode(self.stream.readline()[:-1])
#    1201     logger.debug("Answer received: {0}".format(answer))
#    1202     if answer.startswith(proto.RETURN_MESSAGE):
#
# File /opt/conda/miniconda3/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# KeyboardInterrupt:
